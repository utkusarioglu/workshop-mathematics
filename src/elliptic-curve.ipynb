# %%
# %matplotlib inline
import sympy as sp
import matplotlib.pyplot as plt
# plt.rcParams["figure.figsize"] = 10, 3

# %%
x, y = sp.symbols('x y', int=True)
sp.plot(x**2)

# %%
y = x**3 + 2*x + 3
# sp.plot_parametric(y ** 0.5, x, (x, 1, 2))
sp.plot_parametric(y ** 0.5, x, (x, -10, 2), size=(10, 20))

# %%
d = sp.diff(sp.sin(x**4), x)
# plt.plot(d.series)
d.series()
# Out:
# 4*x**3 + O(x**6)
